# %%
pip install dfply
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import os
from dfply import *

# %%
os.chdir(r'C:\Users\Consultant20162\Desktop\Python Certification\Datesets')

# %%
df=pd.read_csv('adult.csv')

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %% [markdown]
# # Changing columns name

# %%
df=df.rename(columns={'education.num':'education_num', 'marital.status':'marital_status', 'capital.gain':'capital_gain',
                      'capital.loss':'capital_loss', 'hours.per.week':'hours_per_week', 'native.country':'native_country'})

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income'],
#       dtype='object')

# %% [markdown]
# # Selecting columns using dfply

# %%
## Selecting specific columns
(df>>
select(X.age, X.workclass, X.occupation, X.education, X.income))
# Out:
#        age workclass         occupation     education income
# 0       90         ?                  ?       HS-grad  <=50K
# 1       82   Private    Exec-managerial       HS-grad  <=50K
# 2       66         ?                  ?  Some-college  <=50K
# 3       54   Private  Machine-op-inspct       7th-8th  <=50K
# 4       41   Private     Prof-specialty  Some-college  <=50K
# ...    ...       ...                ...           ...    ...
# 32556   22   Private    Protective-serv  Some-college  <=50K
# 32557   27   Private       Tech-support    Assoc-acdm  <=50K
# 32558   40   Private  Machine-op-inspct       HS-grad   >50K
# 32559   58   Private       Adm-clerical       HS-grad  <=50K
# 32560   22   Private       Adm-clerical       HS-grad  <=50K
#
# [32561 rows x 5 columns]

# %% [markdown]
# # Dropping columns using dfply

# %%
## Dropping columns (using not option)
(df>>
select(~X.fnlwgt, ~X.education_num, ~X.capital_gain, ~X.capital_loss))
# Out:
#        age workclass     education      marital_status         occupation  \
# 0       90         ?       HS-grad             Widowed                  ?
# 1       82   Private       HS-grad             Widowed    Exec-managerial
# 2       66         ?  Some-college             Widowed                  ?
# 3       54   Private       7th-8th            Divorced  Machine-op-inspct
# 4       41   Private  Some-college           Separated     Prof-specialty
# ...    ...       ...           ...                 ...                ...
# 32556   22   Private  Some-college       Never-married    Protective-serv
# 32557   27   Private    Assoc-acdm  Married-civ-spouse       Tech-support
# 32558   40   Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 32559   58   Private       HS-grad             Widowed       Adm-clerical
# 32560   22   Private       HS-grad       Never-married       Adm-clerical
#
#         relationship   race     sex  hours_per_week native_country income
# ...

# %%
## Dropping columns
(df>>
drop(X.fnlwgt,X.education_num, X.capital_gain, X.capital_loss))
# Out:
#        age workclass     education      marital_status         occupation  \
# 0       90         ?       HS-grad             Widowed                  ?
# 1       82   Private       HS-grad             Widowed    Exec-managerial
# 2       66         ?  Some-college             Widowed                  ?
# 3       54   Private       7th-8th            Divorced  Machine-op-inspct
# 4       41   Private  Some-college           Separated     Prof-specialty
# ...    ...       ...           ...                 ...                ...
# 32556   22   Private  Some-college       Never-married    Protective-serv
# 32557   27   Private    Assoc-acdm  Married-civ-spouse       Tech-support
# 32558   40   Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 32559   58   Private       HS-grad             Widowed       Adm-clerical
# 32560   22   Private       HS-grad       Never-married       Adm-clerical
#
#         relationship   race     sex  hours_per_week native_country income
# ...

# %% [markdown]
# # Filter rows- Mask Command

# %%
## Filtering records based on conditions
(df>>
mask(X.age>50, X.education=='HS-grad', X.workclass=='Private'))
# Out:
#        age workclass  fnlwgt education  education_num      marital_status  \
# 1       82   Private  132870   HS-grad              9             Widowed
# 22      61   Private   29059   HS-grad              9            Divorced
# 36      53   Private  149650   HS-grad              9       Never-married
# 46      71   Private  110380   HS-grad              9  Married-civ-spouse
# 128     81   Private  177408   HS-grad              9  Married-civ-spouse
# ...    ...       ...     ...       ...            ...                 ...
# 32469   62   Private  128092   HS-grad              9             Widowed
# 32473   66   Private  269665   HS-grad              9             Widowed
# 32495   61   Private  355645   HS-grad              9  Married-civ-spouse
# 32504   57   Private  153918   HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910   HS-grad              9             Widowed
#
#              occupation   relationship   race     sex  capital_gain  \
# ...

# %% [markdown]
# # Sort rows-Arrange Command

# %%
## Sorting rows
(df>>
arrange(X.age, X.hours_per_week, ascending=False)>>
head(10))
# Out:
#        age         workclass  fnlwgt    education  education_num  \
# 17603   90           Private   90523      HS-grad              9
# 1742    90           Private   87372  Prof-school             15
# 1739    90         Local-gov  227796      Masters             14
# 14659   90           Private   40388    Bachelors             13
# 2241    90  Self-emp-not-inc  155981    Bachelors             13
# 2299    90           Private  175491      HS-grad              9
# 8914    90           Private   51744      Masters             14
# 5896    90           Private  221832    Bachelors             13
# 0       90                 ?   77053      HS-grad              9
# 199     90           Private   51744      HS-grad              9
#
#            marital_status        occupation   relationship   race     sex  \
# 17603             Widowed  Transport-moving      Unmarried  White    Male
# 1742   Married-civ-spouse    Prof-specialty        Husband  White    Male
# ...

# %% [markdown]
# # Adding new columns- Mutate Command

# %%
## Creating new column
(df>>
mutate(workclass_education=X.workclass+'-'+X.education, yearly_hours=X.hours_per_week*52))
# Out:
#        age workclass  fnlwgt     education  education_num      marital_status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %% [markdown]
# # Group by

# %%
## group by data
(df>>
group_by(X.sex))
# Out:
#        age workclass  fnlwgt     education  education_num      marital_status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %% [markdown]
# # Summarise Data

# %%
## grouping and find the mean age
(df>>
group_by(X.occupation)>>
summarise(mean_age=X.age.mean()))
# Out:
#            occupation   mean_age
# 0                   ?  40.882800
# 1        Adm-clerical  36.964456
# 2        Armed-Forces  30.222222
# 3        Craft-repair  39.031471
# 4     Exec-managerial  42.169208
# 5     Farming-fishing  41.211268
# 6   Handlers-cleaners  32.165693
# 7   Machine-op-inspct  37.715285
# 8       Other-service  34.949621
# 9     Priv-house-serv  41.724832
# 10     Prof-specialty  40.517633
# 11    Protective-serv  38.953775
# 12              Sales  37.353973
# 13       Tech-support  37.022629
# 14   Transport-moving  40.197871

# %%
df
# Out:
#        age workclass  fnlwgt     education  education_num      marital_status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %% [markdown]
# # Bringing it all

# %%
(df>>
select (~X.fnlwgt, ~X.education_num, ~X.capital_gain, ~X.capital_loss)>>
mask(X.workclass=='Private',X.native_country=='United-States')>>
mutate(Yearly_hours=X.hours_per_week*52)>>
arrange(X.Yearly_hours, ascending=False)>>
group_by(X.occupation)>>
head(20))
# Out:
#        age workclass  education      marital_status        occupation  \
# 7469    56   Private    Masters  Married-civ-spouse      Adm-clerical
# 28658   19   Private    7th-8th       Never-married      Adm-clerical
# 22305   55   Private    7th-8th  Married-civ-spouse      Adm-clerical
# 9796    55   Private  Bachelors            Divorced      Adm-clerical
# 30950   40   Private    HS-grad       Never-married      Adm-clerical
# ...    ...       ...        ...                 ...               ...
# 28360   41   Private       12th            Divorced  Transport-moving
# 22723   33   Private  Assoc-voc  Married-civ-spouse  Transport-moving
# 5795    51   Private    HS-grad  Married-civ-spouse  Transport-moving
# 15117   22   Private    HS-grad  Married-civ-spouse  Transport-moving
# 26112   29   Private    HS-grad   Married-AF-spouse  Transport-moving
#
#          relationship   race     sex  hours_per_week native_country income  \
# ...
