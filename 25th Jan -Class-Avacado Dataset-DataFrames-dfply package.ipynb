# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Consultant20162'

# %%
os.chdir('C:\\Users\\Consultant20162\\Desktop\\Python Certification\\Datesets\\')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Consultant20162\\Desktop\\Python Certification\\Datesets'

# %%
import pandas as pd

# %%
avocado=pd.read_csv('avocado.csv')

# %%
avocado
# Out:
#              Date  AveragePrice  Total Volume  PLU 4046    PLU 4225  \
# 0      12/27/2015          1.33      64236.62    1036.74   54454.85
# 1      12/20/2015          1.35      54876.98     674.28   44638.81
# 2      12/13/2015          0.93     118220.22     794.70  109149.67
# 3       12/6/2015          1.08      78992.15    1132.00   71976.41
# 4      11/29/2015          1.28      51039.60     941.48   43838.39
# ...           ...           ...           ...        ...        ...
# 18244    2/4/2018          1.63      17074.83    2046.96    1529.20
# 18245   1/28/2018          1.71      13888.04    1191.70    3431.50
# 18246   1/21/2018          1.87      13766.76    1191.92    2452.79
# 18247   1/14/2018          1.93      16205.22    1527.63    2981.04
# 18248    1/7/2018          1.62      17489.58    2894.77    2356.13
#
#         PLU 4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 0          48.16     8696.87     8603.62       93.25          0.0
# ...

# %%
len(avocado) # Total rows
# Out:
# 18249

# %%
avocado.columns #Columns Name
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', 'PLU 4046 ', 'PLU 4225',
#        ' PLU 4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags',
#        'type', 'year', 'region'],
#       dtype='object')

# %%
len(avocado.columns) ## total columns
# Out:
# 13

# %%
avocado.head() # first 5 rows
# Out:
#          Date  AveragePrice  Total Volume  PLU 4046    PLU 4225   PLU 4770  \
# 0  12/27/2015          1.33      64236.62    1036.74   54454.85      48.16
# 1  12/20/2015          1.35      54876.98     674.28   44638.81      58.33
# 2  12/13/2015          0.93     118220.22     794.70  109149.67     130.50
# 3   12/6/2015          1.08      78992.15    1132.00   71976.41      72.58
# 4  11/29/2015          1.28      51039.60     941.48   43838.39      75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
avocado.tail() #last 5 rows
# Out:
#             Date  AveragePrice  Total Volume  PLU 4046   PLU 4225   PLU 4770  \
# 18244   2/4/2018          1.63      17074.83    2046.96   1529.20       0.00
# 18245  1/28/2018          1.71      13888.04    1191.70   3431.50       0.00
# 18246  1/21/2018          1.87      13766.76    1191.92   2452.79     727.94
# 18247  1/14/2018          1.93      16205.22    1527.63   2981.04     727.01
# 18248   1/7/2018          1.62      17489.58    2894.77   2356.13     224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    13498.67    13066.82      431.85          0.0  organic  2018
# 18245     9264.84     8940.04      324.80          0.0  organic  2018
# 18246     9394.11     9351.80       42.31          0.0  organic  2018
# 18247    10969.54    10919.54       50.00          0.0  organic  2018
# 18248    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# ...

# %%
avocado.info() # summary of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
# Date            18249 non-null object
# AveragePrice    18249 non-null float64
# Total Volume    18249 non-null float64
# PLU 4046        18249 non-null float64
# PLU 4225        18249 non-null float64
#  PLU 4770       18249 non-null float64
# Total Bags      18249 non-null float64
# Small Bags      18249 non-null float64
# Large Bags      18249 non-null float64
# XLarge Bags     18249 non-null float64
# type            18249 non-null object
# year            18249 non-null int64
# region          18249 non-null object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
avocado.describe()  ## decription of numerical data
# Out:
#        AveragePrice  Total Volume     PLU 4046       PLU 4225      PLU 4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %%
avocado.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', 'PLU 4046 ', 'PLU 4225',
#        ' PLU 4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags',
#        'type', 'year', 'region'],
#       dtype='object')

# %%
## to get the column info, we have to delete the space between the column heading and we will rename it by paasing a dictionary
#inplace =true will keep the headings in place and for permanent(it will overwrite the dataframe)
avocado.rename(columns={'Total Volume':'TotalVolume', 'PLU 4046 ': 'PLU4046', 'PLU 4225':'PLU4225', ' PLU 4770':'PLU4770'}, 
               inplace=True)

# %%
avocado
# Out:
#              Date  AveragePrice  TotalVolume  PLU4046    PLU4225  PLU4770  \
# 0      12/27/2015          1.33     64236.62  1036.74   54454.85    48.16
# 1      12/20/2015          1.35     54876.98   674.28   44638.81    58.33
# 2      12/13/2015          0.93    118220.22   794.70  109149.67   130.50
# 3       12/6/2015          1.08     78992.15  1132.00   71976.41    72.58
# 4      11/29/2015          1.28     51039.60   941.48   43838.39    75.78
# ...           ...           ...          ...      ...        ...      ...
# 18244    2/4/2018          1.63     17074.83  2046.96    1529.20     0.00
# 18245   1/28/2018          1.71     13888.04  1191.70    3431.50     0.00
# 18246   1/21/2018          1.87     13766.76  1191.92    2452.79   727.94
# 18247   1/14/2018          1.93     16205.22  1527.63    2981.04   727.01
# 18248    1/7/2018          1.62     17489.58  2894.77    2356.13   224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
avocado['type'] #  this will give column specific details (which is through index)
# Out:
# 0        conventional
# 1        conventional
# 2        conventional
# 3        conventional
# 4        conventional
#              ...
# 18244         organic
# 18245         organic
# 18246         organic
# 18247         organic
# 18248         organic
# Name: type, Length: 18249, dtype: object

# %%
avocado[1:50].tail() #give 5 rows from bottom out of 50 mentioned
# Out:
#          Date  AveragePrice  TotalVolume  PLU4046   PLU4225  PLU4770  \
# 45  2/15/2015          1.06     41567.62   986.66  30045.51   222.42
# 46   2/8/2015          0.99     51253.97  1357.37  39111.81   163.25
# 47   2/1/2015          0.99     70873.60  1353.90  60017.20   179.32
# 48  1/25/2015          1.06     45147.50   941.38  33196.16   164.14
# 49  1/18/2015          1.17     44511.28   914.14  31540.32   135.77
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 45    10313.03     9979.87      333.16          0.0  conventional  2015
# 46    10621.54    10113.10      508.44          0.0  conventional  2015
# 47     9323.18     9170.82      152.36          0.0  conventional  2015
# 48    10845.82    10103.35      742.47          0.0  conventional  2015
# 49    11921.05    11651.09      269.96          0.0  conventional  2015
#
#     region
# 45  Albany
# 46  Albany
# 47  Albany
# 48  Albany
# 49  Albany

# %%
avocado[['PLU4046', 'type', 'region', 'AveragePrice']] # Getting specific columns
# Out:
#        PLU4046          type            region  AveragePrice
# 0      1036.74  conventional            Albany          1.33
# 1       674.28  conventional            Albany          1.35
# 2       794.70  conventional            Albany          0.93
# 3      1132.00  conventional            Albany          1.08
# 4       941.48  conventional            Albany          1.28
# ...        ...           ...               ...           ...
# 18244  2046.96       organic  WestTexNewMexico          1.63
# 18245  1191.70       organic  WestTexNewMexico          1.71
# 18246  1191.92       organic  WestTexNewMexico          1.87
# 18247  1527.63       organic  WestTexNewMexico          1.93
# 18248  2894.77       organic  WestTexNewMexico          1.62
#
# [18249 rows x 4 columns]

# %%
avocado
# Out:
#              Date  AveragePrice  TotalVolume  PLU4046    PLU4225  PLU4770  \
# 0      12/27/2015          1.33     64236.62  1036.74   54454.85    48.16
# 1      12/20/2015          1.35     54876.98   674.28   44638.81    58.33
# 2      12/13/2015          0.93    118220.22   794.70  109149.67   130.50
# 3       12/6/2015          1.08     78992.15  1132.00   71976.41    72.58
# 4      11/29/2015          1.28     51039.60   941.48   43838.39    75.78
# ...           ...           ...          ...      ...        ...      ...
# 18244    2/4/2018          1.63     17074.83  2046.96    1529.20     0.00
# 18245   1/28/2018          1.71     13888.04  1191.70    3431.50     0.00
# 18246   1/21/2018          1.87     13766.76  1191.92    2452.79   727.94
# 18247   1/14/2018          1.93     16205.22  1527.63    2981.04   727.01
# 18248    1/7/2018          1.62     17489.58  2894.77    2356.13   224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
avocado[1:101][['PLU4046', 'PLU4225', 'PLU4770', 'AveragePrice', 'type', 'region']]
## fetch column specific rows from top 100 rows
# Out:
#        PLU4046    PLU4225  PLU4770  AveragePrice          type   region
# 1       674.28   44638.81    58.33          1.35  conventional   Albany
# 2       794.70  109149.67   130.50          0.93  conventional   Albany
# 3      1132.00   71976.41    72.58          1.08  conventional   Albany
# 4       941.48   43838.39    75.78          1.28  conventional   Albany
# 5      1184.27   48067.99    43.61          1.26  conventional   Albany
# ..         ...        ...      ...           ...           ...      ...
# 96   369316.29   18324.76   237.47          1.10  conventional  Atlanta
# 97   364446.77   17420.41   638.18          1.06  conventional  Atlanta
# 98   377256.38   17162.50   524.85          1.03  conventional  Atlanta
# 99   553198.56   31583.38   294.94          0.96  conventional  Atlanta
# 100  393408.17   18718.27   594.25          1.10  conventional  Atlanta
#
# [100 rows x 6 columns]

# %%
len(avocado.region.unique()) ## total no. unique values in region column
# Out:
# 54

# %%
avocado.region.unique() ## uniques values in column(region)
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
avocado[(avocado['region']=='Albany') | (avocado['region']=='Atlanta') ## Or condition with all columns data
# Out:
#              Date  AveragePrice  TotalVolume  PLU4046    PLU4225  PLU4770  \
# 0      12/27/2015          1.33     64236.62  1036.74   54454.85    48.16
# 1      12/20/2015          1.35     54876.98   674.28   44638.81    58.33
# 2      12/13/2015          0.93    118220.22   794.70  109149.67   130.50
# 3       12/6/2015          1.08     78992.15  1132.00   71976.41    72.58
# 4      11/29/2015          1.28     51039.60   941.48   43838.39    75.78
# ...           ...           ...          ...      ...        ...      ...
# 17620    2/4/2018          1.62     11900.41   384.29    4042.55     0.00
# 17621   1/28/2018          1.67     14446.26   390.17    5130.48     0.00
# 17622   1/21/2018          1.64     18554.97   349.05    3967.66     0.00
# 17623   1/14/2018          1.56     16151.70   291.55    3583.40     0.00
# 17624    1/7/2018          1.53     15714.11   405.37    4195.19     0.00
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
avocado[(avocado['region']=='Albany') | (avocado['region']=='Atlanta')][['AveragePrice', 'PLU4046', 'region' ]] 
## Or condition with columns specific data
# Out:
#        AveragePrice  PLU4046   region
# 0              1.33  1036.74   Albany
# 1              1.35   674.28   Albany
# 2              0.93   794.70   Albany
# 3              1.08  1132.00   Albany
# 4              1.28   941.48   Albany
# ...             ...      ...      ...
# 17620          1.62   384.29  Atlanta
# 17621          1.67   390.17  Atlanta
# 17622          1.64   349.05  Atlanta
# 17623          1.56   291.55  Atlanta
# 17624          1.53   405.37  Atlanta
#
# [676 rows x 3 columns]

# %%
avocado[avocado['region'].isin(['Albany', 'Atlanta', 'Houston', 'detroit'])]
## how to pass multiple conditions (.isin command)
# Out:
#              Date  AveragePrice  TotalVolume   PLU4046    PLU4225  PLU4770  \
# 0      12/27/2015          1.33     64236.62   1036.74   54454.85    48.16
# 1      12/20/2015          1.35     54876.98    674.28   44638.81    58.33
# 2      12/13/2015          0.93    118220.22    794.70  109149.67   130.50
# 3       12/6/2015          1.08     78992.15   1132.00   71976.41    72.58
# 4      11/29/2015          1.28     51039.60    941.48   43838.39    75.78
# ...           ...           ...          ...       ...        ...      ...
# 17824    2/4/2018          1.43     27155.44  10163.94     216.52     0.00
# 17825   1/28/2018          1.45     26854.20  10288.17     114.77     0.00
# 17826   1/21/2018          1.41     32722.61   7335.69      43.11     0.00
# 17827   1/14/2018          1.49     35522.77  11013.42     108.93     0.00
# 17828    1/7/2018          1.38     30428.43   9238.55      61.24     0.00
#
# ...

# %%
avocado.columns
# Out:
# Index(['Date', 'AveragePrice', 'TotalVolume', 'PLU4046', 'PLU4225', 'PLU4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
avocado['Total_PLU']=(avocado.PLU4046 + avocado.PLU4225 +avocado.PLU4770) ## performing calculations

# %%
avocado
# Out:
#              Date  AveragePrice  TotalVolume  PLU4046    PLU4225  PLU4770  \
# 0      12/27/2015          1.33     64236.62  1036.74   54454.85    48.16
# 1      12/20/2015          1.35     54876.98   674.28   44638.81    58.33
# 2      12/13/2015          0.93    118220.22   794.70  109149.67   130.50
# 3       12/6/2015          1.08     78992.15  1132.00   71976.41    72.58
# 4      11/29/2015          1.28     51039.60   941.48   43838.39    75.78
# ...           ...           ...          ...      ...        ...      ...
# 18244    2/4/2018          1.63     17074.83  2046.96    1529.20     0.00
# 18245   1/28/2018          1.71     13888.04  1191.70    3431.50     0.00
# 18246   1/21/2018          1.87     13766.76  1191.92    2452.79   727.94
# 18247   1/14/2018          1.93     16205.22  1527.63    2981.04   727.01
# 18248    1/7/2018          1.62     17489.58  2894.77    2356.13   224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
avocado.sort_values(['Total_PLU'],ascending=0)
### sorting according to 'Total_PLU' column
# Out:
#           Date  AveragePrice  TotalVolume      PLU4046      PLU4225  \
# 8366  2/5/2017          0.77  61034457.10  22743616.17  20328161.55
# 9097  2/4/2018          0.87  62505646.52  21620180.90  20445501.03
# 5506  2/7/2016          0.76  52288697.89  16573573.78  20470572.61
# 2699  2/1/2015          0.89  44655461.51  18933038.04  18956479.74
# 2686  5/3/2015          0.96  41291704.39  17787611.93  16602589.04
#
#          PLU4770   Total Bags   Small Bags  Large Bags  XLarge Bags  \
# 8366  1664383.09  16298296.29  12567155.58  3618270.75    112869.96
# 9097  1066830.22  19373134.37  13384586.80  5719096.61    269450.96
# 5506  2546439.11  12698112.39   9083373.04  3373077.87    241661.48
# 2699  1381516.11   5384427.62   4216452.03  1121076.47     46899.12
# 2686  1118329.50   5783173.92   4647155.48  1110987.23     25031.21
#
#               type  year   region    Total_PLU
# 8366  conventional  2017  TotalUS  44736160.81
# 9097  conventional  2018  TotalUS  43132512.15
# ...

# %%
avocado.drop(['Total_PLU'], axis=1, inplace=True) ##Delete Total_PLU column from the dataset

# %%
avocado
# Out:
#              Date  AveragePrice  TotalVolume  PLU4046    PLU4225  PLU4770  \
# 0      12/27/2015          1.33     64236.62  1036.74   54454.85    48.16
# 1      12/20/2015          1.35     54876.98   674.28   44638.81    58.33
# 2      12/13/2015          0.93    118220.22   794.70  109149.67   130.50
# 3       12/6/2015          1.08     78992.15  1132.00   71976.41    72.58
# 4      11/29/2015          1.28     51039.60   941.48   43838.39    75.78
# ...           ...           ...          ...      ...        ...      ...
# 18244    2/4/2018          1.63     17074.83  2046.96    1529.20     0.00
# 18245   1/28/2018          1.71     13888.04  1191.70    3431.50     0.00
# 18246   1/21/2018          1.87     13766.76  1191.92    2452.79   727.94
# 18247   1/14/2018          1.93     16205.22  1527.63    2981.04   727.01
# 18248    1/7/2018          1.62     17489.58  2894.77    2356.13   224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
## filtering on the basis of condition (1-way)
# Out:
#              Date  AveragePrice  TotalVolume  PLU4046   PLU4225  PLU4770  \
# 0      12/27/2015          1.33     64236.62  1036.74  54454.85    48.16
# 1      12/20/2015          1.35     54876.98   674.28  44638.81    58.33
# 3       12/6/2015          1.08     78992.15  1132.00  71976.41    72.58
# 4      11/29/2015          1.28     51039.60   941.48  43838.39    75.78
# 5      11/22/2015          1.26     55979.78  1184.27  48067.99    43.61
# ...           ...           ...          ...      ...       ...      ...
# 18244    2/4/2018          1.63     17074.83  2046.96   1529.20     0.00
# 18245   1/28/2018          1.71     13888.04  1191.70   3431.50     0.00
# 18246   1/21/2018          1.87     13766.76  1191.92   2452.79   727.94
# 18247   1/14/2018          1.93     16205.22  1527.63   2981.04   727.01
# 18248    1/7/2018          1.62     17489.58  2894.77   2356.13   224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
avocado[avocado['AveragePrice']>1] ## filtering on the basis of condition (2-way)
# Out:
#              Date  AveragePrice  TotalVolume  PLU4046   PLU4225  PLU4770  \
# 0      12/27/2015          1.33     64236.62  1036.74  54454.85    48.16
# 1      12/20/2015          1.35     54876.98   674.28  44638.81    58.33
# 3       12/6/2015          1.08     78992.15  1132.00  71976.41    72.58
# 4      11/29/2015          1.28     51039.60   941.48  43838.39    75.78
# 5      11/22/2015          1.26     55979.78  1184.27  48067.99    43.61
# ...           ...           ...          ...      ...       ...      ...
# 18244    2/4/2018          1.63     17074.83  2046.96   1529.20     0.00
# 18245   1/28/2018          1.71     13888.04  1191.70   3431.50     0.00
# 18246   1/21/2018          1.87     13766.76  1191.92   2452.79   727.94
# 18247   1/14/2018          1.93     16205.22  1527.63   2981.04   727.01
# 18248    1/7/2018          1.62     17489.58  2894.77   2356.13   224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
avocado.type.unique() ## find unique value (type)
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
avocado.year.unique() ## find unique value (year)
# Out:
# array([2015, 2016, 2017, 2018], dtype=int64)

# %%
avocado.region.unique() ## find unique value (region)
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
# Date            18249 non-null object
# AveragePrice    18249 non-null float64
# TotalVolume     18249 non-null float64
# PLU4046         18249 non-null float64
# PLU4225         18249 non-null float64
# PLU4770         18249 non-null float64
# Total Bags      18249 non-null float64
# Small Bags      18249 non-null float64
# Large Bags      18249 non-null float64
# XLarge Bags     18249 non-null float64
# type            18249 non-null object
# year            18249 non-null int64
# region          18249 non-null object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
avocado.columns
# Out:
# Index(['Date', 'AveragePrice', 'TotalVolume', 'PLU4046', 'PLU4225', 'PLU4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
## Scatterplot
sns.lmplot(data=avocado,x='AveragePrice', y='TotalVolume', hue='year', fit_reg=False)

# %%
#### dpfly pacakge
## its npt availble Anaconda therefore we have to install this

# %%
# !pip install dfply ## install the package

# %%
from dfply import*

# %%
import dfply

# %%
avocado
# Out:
#              Date  AveragePrice  Total Volume  PLU 4046    PLU 4225  \
# 0      12/27/2015          1.33      64236.62    1036.74   54454.85
# 1      12/20/2015          1.35      54876.98     674.28   44638.81
# 2      12/13/2015          0.93     118220.22     794.70  109149.67
# 3       12/6/2015          1.08      78992.15    1132.00   71976.41
# 4      11/29/2015          1.28      51039.60     941.48   43838.39
# ...           ...           ...           ...        ...        ...
# 18244    2/4/2018          1.63      17074.83    2046.96    1529.20
# 18245   1/28/2018          1.71      13888.04    1191.70    3431.50
# 18246   1/21/2018          1.87      13766.76    1191.92    2452.79
# 18247   1/14/2018          1.93      16205.22    1527.63    2981.04
# 18248    1/7/2018          1.62      17489.58    2894.77    2356.13
#
#         PLU 4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 0          48.16     8696.87     8603.62       93.25          0.0
# ...

# %%
avocado.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', 'PLU 4046 ', 'PLU 4225',
#        ' PLU 4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags',
#        'type', 'year', 'region'],
#       dtype='object')

# %%
## extracting columns using dfply 
(avocado>>
 select(X.AveragePrice,  X.year , X.region)>>
 head())
# Out:
#    AveragePrice  year  region
# 0          1.33  2015  Albany
# 1          1.35  2015  Albany
# 2          0.93  2015  Albany
# 3          1.08  2015  Albany
# 4          1.28  2015  Albany

# %%
## if we dont want any specific column
(avocado>>
 select (~ X.AveragePrice,  ~X.year , ~X.region))
# Out:
#              Date  Total Volume  PLU 4046    PLU 4225   PLU 4770  Total Bags  \
# 0      12/27/2015      64236.62    1036.74   54454.85      48.16     8696.87
# 1      12/20/2015      54876.98     674.28   44638.81      58.33     9505.56
# 2      12/13/2015     118220.22     794.70  109149.67     130.50     8145.35
# 3       12/6/2015      78992.15    1132.00   71976.41      72.58     5811.16
# 4      11/29/2015      51039.60     941.48   43838.39      75.78     6183.95
# ...           ...           ...        ...        ...        ...         ...
# 18244    2/4/2018      17074.83    2046.96    1529.20       0.00    13498.67
# 18245   1/28/2018      13888.04    1191.70    3431.50       0.00     9264.84
# 18246   1/21/2018      13766.76    1191.92    2452.79     727.94     9394.11
# 18247   1/14/2018      16205.22    1527.63    2981.04     727.01    10969.54
# 18248    1/7/2018      17489.58    2894.77    2356.13     224.53    12014.15
#
# ...

# %%
## mask- function is used to filter the rows
(avocado>>
mask(X.AveragePrice>1, X.type=='organic', X.region== 'Boise'))
# Out:
#              Date  AveragePrice  Total Volume  PLU 4046   PLU 4225   PLU 4770  \
# 9283   12/20/2015          1.17       1807.57      10.29    409.07       0.00
# 9285    12/6/2015          1.36       1286.83      11.75    533.55       0.00
# 9286   11/29/2015          1.34       1047.42       2.59    418.01       0.00
# 9287   11/22/2015          1.54       1000.86       7.77    724.33       2.59
# 9288   11/15/2015          1.78        881.14      17.27    538.40       0.00
# ...           ...           ...           ...        ...       ...        ...
# 17644    2/4/2018          1.80       2594.90      76.84    590.46       0.00
# 17645   1/28/2018          1.78       2419.64      52.42    580.64       0.00
# 17646   1/21/2018          1.81       2446.13      41.05    577.32       0.00
# 17647   1/14/2018          1.81       2130.13      51.93    802.89       0.00
# 17648    1/7/2018          1.77       2553.90      42.60    949.08       0.00
#
# ...

# %%
## filtering the rows and selecting specific column
(avocado>>
select(X.AveragePrice, X.type, X.region)>>
mask(X.AveragePrice>1, X.type=='organic', X.region== 'Boise'))
# Out:
#        AveragePrice     type region
# 9283           1.17  organic  Boise
# 9285           1.36  organic  Boise
# 9286           1.34  organic  Boise
# 9287           1.54  organic  Boise
# 9288           1.78  organic  Boise
# ...             ...      ...    ...
# 17644          1.80  organic  Boise
# 17645          1.78  organic  Boise
# 17646          1.81  organic  Boise
# 17647          1.81  organic  Boise
# 17648          1.77  organic  Boise
#
# [156 rows x 3 columns]

# %%
##arrange sorts the data 
(avocado>>
arrange(X.AveragePrice,ascending=False))
# Out:
#              Date  AveragePrice  Total Volume   PLU 4046    PLU 4225  \
# 14125  10/30/2016          3.25      16700.94     2325.93   11142.85
# 17428   4/16/2017          3.17       3018.56     1255.55      82.31
# 14124   11/6/2016          3.12      19043.80     5898.49   10039.34
# 16055   3/12/2017          3.05       2068.26     1043.83      77.36
# 16720   8/27/2017          3.04      12656.32      419.06    4851.90
# ...           ...           ...           ...         ...        ...
# 1716   12/27/2015          0.49    1137707.43   738314.80  286858.37
# 15262   2/26/2017          0.49      44024.03      252.79    4472.68
# 15473    3/5/2017          0.48      50890.73      717.57    4138.84
# 7412     2/5/2017          0.46    2200550.27  1200632.86  531226.65
# 15261    3/5/2017          0.44      64057.04      223.84    4748.88
#
#         PLU 4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 14125       0.00     3232.16     3232.16        0.00         0.00
# ...

# %%
#mutate command is used to calculate anything or concatenation(creating a new column)
(avocado>>
mutate(type_region=X.type+ '-'+ X.region)>>
head())
# Out:
#          Date  AveragePrice  Total Volume  PLU 4046    PLU 4225   PLU 4770  \
# 0  12/27/2015          1.33      64236.62    1036.74   54454.85      48.16
# 1  12/20/2015          1.35      54876.98     674.28   44638.81      58.33
# 2  12/13/2015          0.93     118220.22     794.70  109149.67     130.50
# 3   12/6/2015          1.08      78992.15    1132.00   71976.41      72.58
# 4  11/29/2015          1.28      51039.60     941.48   43838.39      75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region          type_region
# 0  Albany  conventional-Albany
# ...

# %%
## group by
(avocado>>
group_by(X.AveragePrice)>>
summarise(mean_AveragePrice=X.AveragePrice.mean))
# Out:
#      AveragePrice                                  mean_AveragePrice
# 0            0.44  <bound method Series.mean of 14125    0.44\nNa...
# 1            0.46  <bound method Series.mean of 14125    0.46\nNa...
# 2            0.48  <bound method Series.mean of 14125    0.48\nNa...
# 3            0.49  <bound method Series.mean of 14125    0.49\n  ...
# 4            0.51  <bound method Series.mean of 14125    0.51\n  ...
# ..            ...                                                ...
# 254          3.04  <bound method Series.mean of 14125    3.04\nNa...
# 255          3.05  <bound method Series.mean of 14125    3.05\nNa...
# 256          3.12  <bound method Series.mean of 14125    3.12\nNa...
# 257          3.17  <bound method Series.mean of 14125    3.17\nNa...
# 258          3.25  <bound method Series.mean of 14125    3.25\nNa...
#
# [259 rows x 2 columns]
