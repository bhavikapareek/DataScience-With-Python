# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns

# %%
os.chdir(r'C:\Users\Consultant20162\Desktop\Python Certification\Datesets')

# %%
df=pd.read_excel('Housing Prices.xlsx')

# %%
df
# Out:
#          d  LotFrontage  LotArea Alley  MasVnrArea  1stFlrSF  2ndFlrSF  \
# 0        1         65.0     8450   NaN       196.0       856       854
# 1        2         80.0     9600   NaN         0.0      1262         0
# 2        3         68.0    11250   NaN       162.0       920       866
# 3        4         60.0     9550   NaN         0.0       961       756
# 4        5         84.0    14260   NaN       350.0      1145      1053
# ...    ...          ...      ...   ...         ...       ...       ...
# 1455  1456         62.0     7917   NaN         0.0       953       694
# 1456  1457         85.0    13175   NaN       119.0      2073         0
# 1457  1458         66.0     9042   NaN         0.0      1188      1152
# 1458  1459         68.0     9717   NaN         0.0      1078         0
# 1459  1460         75.0     9937   NaN         0.0      1256         0
#
#       GrLivArea GarageType  GarageArea  SalePrice
# 0          1710     Attchd         548     208500
# ...

# %% [markdown]
# # Missing Value Treatment

# %%
#If in any column 25% of data is missing, we will removen that column
df.isnull().sum()/len(df)*100
# Out:
# d               0.000000
# LotFrontage    17.739726
# LotArea         0.000000
# Alley          93.767123
# MasVnrArea      0.547945
# 1stFlrSF        0.000000
# 2ndFlrSF        0.000000
# GrLivArea       0.000000
# GarageType      5.547945
# GarageArea      0.000000
# SalePrice       0.000000
# dtype: float64

# %%
## remove column Alley
df_1 = df

# %%
df_1
# Out:
#          d  LotFrontage  LotArea Alley  MasVnrArea  1stFlrSF  2ndFlrSF  \
# 0        1         65.0     8450   NaN       196.0       856       854
# 1        2         80.0     9600   NaN         0.0      1262         0
# 2        3         68.0    11250   NaN       162.0       920       866
# 3        4         60.0     9550   NaN         0.0       961       756
# 4        5         84.0    14260   NaN       350.0      1145      1053
# ...    ...          ...      ...   ...         ...       ...       ...
# 1455  1456         62.0     7917   NaN         0.0       953       694
# 1456  1457         85.0    13175   NaN       119.0      2073         0
# 1457  1458         66.0     9042   NaN         0.0      1188      1152
# 1458  1459         68.0     9717   NaN         0.0      1078         0
# 1459  1460         75.0     9937   NaN         0.0      1256         0
#
#       GrLivArea GarageType  GarageArea  SalePrice
# 0          1710     Attchd         548     208500
# ...

# %%
## dropping Column
df_1=df_1.drop(['Alley'], axis=1)

# %%
# Converting dataset into an array
x=df_1.values

# %%
## Imputing column MasVnrArea with median value
df_1['LotFrontage']=df_1['LotFrontage'].fillna(df_1['LotFrontage'].median())

# %%
## Imputing column MasVnrArea with median value
df_1['MasVnrArea']=df_1['MasVnrArea'].fillna(df_1['MasVnrArea'].median())

# %%
## Imputing column GarageType with mode value, it is categorical variable i..e Attchd
df_1['GarageType']=df_1['GarageType'].fillna('Attchd')

# %%
## Checking for Missing Values
df_1.isnull().sum()
# Out:
# d              0
# LotFrontage    0
# LotArea        0
# MasVnrArea     0
# 1stFlrSF       0
# 2ndFlrSF       0
# GrLivArea      0
# GarageType     0
# GarageArea     0
# SalePrice      0
# dtype: int64

# %%
df_1
# Out:
#          d  LotFrontage  LotArea  MasVnrArea  1stFlrSF  2ndFlrSF  GrLivArea  \
# 0        1         65.0     8450       196.0       856       854       1710
# 1        2         80.0     9600         0.0      1262         0       1262
# 2        3         68.0    11250       162.0       920       866       1786
# 3        4         60.0     9550         0.0       961       756       1717
# 4        5         84.0    14260       350.0      1145      1053       2198
# ...    ...          ...      ...         ...       ...       ...        ...
# 1455  1456         62.0     7917         0.0       953       694       1647
# 1456  1457         85.0    13175       119.0      2073         0       2073
# 1457  1458         66.0     9042         0.0      1188      1152       2340
# 1458  1459         68.0     9717         0.0      1078         0       1078
# 1459  1460         75.0     9937         0.0      1256         0       1256
#
#      GarageType  GarageArea  SalePrice
# ...

# %% [markdown]
# # Outlier Treatment

# %%
sns.boxplot(data=df_1, color='red')

# %%
## Dataset
df_1
# Out:
#          d  LotFrontage  LotArea  MasVnrArea  1stFlrSF  2ndFlrSF  GrLivArea  \
# 0        1         65.0     8450       196.0       856       854       1710
# 1        2         80.0     9600         0.0      1262         0       1262
# 2        3         68.0    11250       162.0       920       866       1786
# 3        4         60.0     9550         0.0       961       756       1717
# 4        5         84.0    14260       350.0      1145      1053       2198
# ...    ...          ...      ...         ...       ...       ...        ...
# 1455  1456         62.0     7917         0.0       953       694       1647
# 1456  1457         85.0    13175       119.0      2073         0       2073
# 1457  1458         66.0     9042         0.0      1188      1152       2340
# 1458  1459         68.0     9717         0.0      1078         0       1078
# 1459  1460         75.0     9937         0.0      1256         0       1256
#
#      GarageType  GarageArea  SalePrice
# ...

# %%
# No .of rows and columns
df_1.shape
# Out:
# (1460, 10)

# %%
df_3=df_1

# %%
df_3
# Out:
#          d  LotFrontage  LotArea  MasVnrArea  1stFlrSF  2ndFlrSF  GrLivArea  \
# 0        1         65.0     8450       196.0       856       854       1710
# 1        2         80.0     9600         0.0      1262         0       1262
# 2        3         68.0    11250       162.0       920       866       1786
# 3        4         60.0     9550         0.0       961       756       1717
# 4        5         84.0    14260       350.0      1145      1053       2198
# ...    ...          ...      ...         ...       ...       ...        ...
# 1455  1456         62.0     7917         0.0       953       694       1647
# 1456  1457         85.0    13175       119.0      2073         0       2073
# 1457  1458         66.0     9042         0.0      1188      1152       2340
# 1458  1459         68.0     9717         0.0      1078         0       1078
# 1459  1460         75.0     9937         0.0      1256         0       1256
#
#      GarageType  GarageArea  SalePrice
# ...

# %%
## Calculating Q1 & Q2
Q1=df_3.quantile(0.25)
Q3=df_3.quantile(0.75)

# %%
Q1
# Out:
# d                 365.75
# LotFrontage        60.00
# LotArea          7553.50
# MasVnrArea          0.00
# 1stFlrSF          882.00
# 2ndFlrSF            0.00
# GrLivArea        1129.50
# GarageArea        334.50
# SalePrice      129975.00
# Name: 0.25, dtype: float64

# %%
Q3
# Out:
# d                1095.25
# LotFrontage        79.00
# LotArea         11601.50
# MasVnrArea        164.25
# 1stFlrSF         1391.25
# 2ndFlrSF          728.00
# GrLivArea        1776.75
# GarageArea        576.00
# SalePrice      214000.00
# Name: 0.75, dtype: float64

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# d                729.50
# LotFrontage       19.00
# LotArea         4048.00
# MasVnrArea       164.25
# 1stFlrSF         509.25
# 2ndFlrSF         728.00
# GrLivArea        647.25
# GarageArea       241.50
# SalePrice      84025.00
# dtype: float64

# %%
data_out = df_3[~((df_3 < (Q1-1.5*IQR)) | (df_3>(Q3+1.5*IQR))).any(axis=1)]

# %%
data_out
# Out:
#          d  LotFrontage  LotArea  MasVnrArea  1stFlrSF  2ndFlrSF  GrLivArea  \
# 0        1         65.0     8450       196.0       856       854       1710
# 1        2         80.0     9600         0.0      1262         0       1262
# 2        3         68.0    11250       162.0       920       866       1786
# 3        4         60.0     9550         0.0       961       756       1717
# 4        5         84.0    14260       350.0      1145      1053       2198
# ...    ...          ...      ...         ...       ...       ...        ...
# 1455  1456         62.0     7917         0.0       953       694       1647
# 1456  1457         85.0    13175       119.0      2073         0       2073
# 1457  1458         66.0     9042         0.0      1188      1152       2340
# 1458  1459         68.0     9717         0.0      1078         0       1078
# 1459  1460         75.0     9937         0.0      1256         0       1256
#
#      GarageType  GarageArea  SalePrice
# ...

# %%
data_out.shape
# Out:
# (1179, 10)

# %% [markdown]
# # Feature Scaling

# %%
df_4=df_1

# %%
df_4
# Out:
#          d  LotFrontage  LotArea  MasVnrArea  1stFlrSF  2ndFlrSF  GrLivArea  \
# 0        1         65.0     8450       196.0       856       854       1710
# 1        2         80.0     9600         0.0      1262         0       1262
# 2        3         68.0    11250       162.0       920       866       1786
# 3        4         60.0     9550         0.0       961       756       1717
# 4        5         84.0    14260       350.0      1145      1053       2198
# ...    ...          ...      ...         ...       ...       ...        ...
# 1455  1456         62.0     7917         0.0       953       694       1647
# 1456  1457         85.0    13175       119.0      2073         0       2073
# 1457  1458         66.0     9042         0.0      1188      1152       2340
# 1458  1459         68.0     9717         0.0      1078         0       1078
# 1459  1460         75.0     9937         0.0      1256         0       1256
#
#      GarageType  GarageArea  SalePrice
# ...

# %%
x=df_4[['LotArea', 'GrLivArea']].values

# %%
x
# Out:
# array([[ 8450,  1710],
#        [ 9600,  1262],
#        [11250,  1786],
#        ...,
#        [ 9042,  2340],
#        [ 9717,  1078],
#        [ 9937,  1256]], dtype=int64)

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler
standard_x=StandardScaler()
x_stand=standard_x.fit_transform(x)

# %%
x_stand
# Out:
# array([[-0.20714171,  0.37033344],
#        [-0.09188637, -0.48251191],
#        [ 0.07347998,  0.51501256],
#        ...,
#        [-0.14781027,  1.56964722],
#        [-0.08016039, -0.83278768],
#        [-0.05811155, -0.49393395]])

# %% [markdown]
# # Normalization

# %%
from sklearn.preprocessing import Normalizer
normal_x=Normalizer()
x_norm=normal_x.fit_transform(x)

# %%
x_norm
# Out:
# array([[0.98013202, 0.19834624],
#        [0.99146976, 0.13033696],
#        [0.98763164, 0.15679201],
#        ...,
#        [0.96810663, 0.25053854],
#        [0.99390243, 0.11026313],
#        [0.99210644, 0.12539858]])
